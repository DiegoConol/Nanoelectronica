# %%
import tuputamadre

np.pito(2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tuputamadre
#       3 np.pito(2)
#
# ModuleNotFoundError: No module named 'tuputamadre'
